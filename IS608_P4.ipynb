# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import gmean
from bokeh.charts import TimeSeries, show, output_file, BoxPlot, Bar, Scatter, Histogram
from bokeh.io import output_notebook
import seaborn as sns
# import plotly.plotly as py
# import plotly.graph_objs as go
# %matplotlib inline
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ***
# ## Get started with our data
# We're grabbing the raw .csv file from Charley's github folder.
# ***

# %%
df = pd.read_csv("https://raw.githubusercontent.com/charleyferrari/CUNY_DATA608/master/lecture4/Data/riverkeeper_data_2013.csv")

# %% [markdown]
# ### Have a peek
# Here's the structure; looking deeper shows that the EnteroCount variable has some slop: the entries include "<" and ">" signs that we'll need to remove.

# %%
df.head()
# Out:
#                         Site        Date EnteroCount  FourDayRainTotal  \
# 0  Hudson above Mohawk River  10/16/2011        1733               1.5
# 1  Hudson above Mohawk River  10/21/2013           4               0.2
# 2  Hudson above Mohawk River   9/21/2013          20               0.0
# 3  Hudson above Mohawk River   8/19/2013           6               0.0
# 4  Hudson above Mohawk River   7/21/2013          31               0.0
#
#    SampleCount
# 0           35
# 1           35
# 2           35
# 3           35
# 4           35

# %% [markdown]
# ### Check data types
# Indeed, Date and EnteroCount are the wrong types; they need to be Date and Integer, respectively.

# %%
df.dtypes
# Out:
# Site                 object
# Date                 object
# EnteroCount          object
# FourDayRainTotal    float64
# SampleCount           int64
# dtype: object

# %% [markdown]
# ### Fix data types, stray characters
# Transform 'em while you got 'em. We'll use pandas to make the Date field DateTime.

# %%
df['EnteroCount'].replace('<', "", regex=True, inplace=True)

# %%
df['EnteroCount'].replace('>', "", regex=True, inplace=True)

# %%
df['EnteroCount'] = df['EnteroCount'].astype(int)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ### That's better.

# %%
df.dtypes
# Out:
# Site                        object
# Date                datetime64[ns]
# EnteroCount                  int64
# FourDayRainTotal           float64
# SampleCount                  int64
# dtype: object

# %%
df.head()
# Out:
#                         Site       Date  EnteroCount  FourDayRainTotal  \
# 0  Hudson above Mohawk River 2011-10-16         1733               1.5
# 1  Hudson above Mohawk River 2013-10-21            4               0.2
# 2  Hudson above Mohawk River 2013-09-21           20               0.0
# 3  Hudson above Mohawk River 2013-08-19            6               0.0
# 4  Hudson above Mohawk River 2013-07-21           31               0.0
#
#    SampleCount
# 0           35
# 1           35
# 2           35
# 3           35
# 4           35

# %% [markdown]
# ### Unique sites
# There are 75 unique measuring sites.

# %%
len(df['Site'].unique())
# Out:
# 75

# %% [markdown]
# ***
# ## Best and Worst Places to Swim
# We'll look at mean and geometric mean measurements of Enterococcus levels by site, then sort by contamination levels.
# ***

# %% [markdown]
# ### A function to get some stats
# We'll apply his to each variable to get max, min, count and a mean.

# %%
# function to calculate group stats; used with apply()
def get_stats(group):
    return {'min': group.min(), 'max': group.max(), 'count': group.count(), 'mean': group.mean()}

# %% [markdown]
# ### Highest Geometric mean Enterococcus readings
# After computing the stats, here are the worst 10 sites by overall average contamination. No surprise if you've been on the Gowanus (now a rapidly gentrifying area for Brookly hipsters). Don't swim there. There is no method in pandas to calc the geometric mean, so we have to do it in regular Python using the gmean() function from scipy. Arrrgh.

# %%
grouped_df = df.groupby(['Site'])

# %% [markdown]
# ### Highest Geometric Mean Enteroccocus readings
# Slightly different ranking, but all well above the 30/mL standard.

# %%
grouped_df['EnteroCount'].apply(gmean, axis=None).reset_index().sort_values(by='EnteroCount', ascending=0)[0:9]
# Out:
#                                        Site  EnteroCount
# 70                     Upper Sparkill Creek   387.184599
# 29                            Gowanus Canal   181.330620
# 45                Mohawk River at Waterford   169.718920
# 48  Newtown Creek- Metropolitan Ave. Bridge   147.728997
# 63                           Saw Mill River   115.117277
# 57                            Piermont Pier   106.641987
# 34             Hudson River above Troy Lock   105.365758
# 46                     Newburgh Launch Ramp   102.579356
# 41                     Kingston STP Outfall   102.225027

# %% [markdown]
# ### Lowest Geometric Mean Enteroccocus readings
# Keepin' it clean upstate. How about them Catskills?

# %%
grouped_df['EnteroCount'].apply(gmean, axis=None).reset_index().sort_values(by='EnteroCount', ascending=1)[0:9]
# Out:
#                                   Site  EnteroCount
# 10        Catskill Creek- First Bridge     0.000000
# 50            Norrie Point mid-channel     3.909624
# 59  Poughkeepsie Drinking Water Intake     4.381236
# 58     Port Ewen Drinking Water Intake     5.257241
# 68                      Tivoli Landing     6.926002
# 42                  Little Stony Point     7.887391
# 69                Ulster Landing Beach     8.779956
# 72              West Point STP Outfall     9.210815
# 44                    Marlboro Landing     9.661643

# %% [markdown]
# ### Plot Best and Worst
# Unfortunately, Bokeh would not let me override the default alphabetical sort on the x-axis label names. I have no idea why. I tried the code in the docs: labels = cat('Site', sort=False). I do like the way it automatically 45s the long label names.

# %%
df_geo = grouped_df['EnteroCount'].apply(gmean, axis=None).reset_index().sort_values(by='EnteroCount', ascending=1)

# %%
worst = df_geo.tail(20).sort_values('EnteroCount', ascending=1)

# %%
best = df_geo.head(20).sort_values('EnteroCount', ascending=1)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2f305c66-d967-47c6-b047-f1d28d241217">Loading BokehJS ...</span>
#     </div>

# %%
p = Bar(worst, 'Site', values='EnteroCount', 
            title="Worst 20 Enterococcus readings by Site",
            color="lightblue", legend=False, xlabel="")

output_file("bar.html")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c359e454-b0ea-439a-9494-e6f75deb2644"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c359e454-b0ea-439a-9494-e6f75deb2644").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c359e454-b0ea-439a-9494-e6f75deb2644");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c359e454-b0ea-439a-9494-e6f75deb2644' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9be638e4-76d2-4820-953f-9b581b751dcc":{"roots":{"references":[{"attributes":{"plot":{"id":"8b9aee70-1823-4c77-9927-768138a540f6","subtype":"Chart","type":"Plot"}},"id":"f1df2213-8b6c-4ca5-9872-90907fe33a25","type":"ResetTool"},{"attributes":{"data_source":{"id":"856661a1-0714-4934-b653-e8b45fc6e146","type":"ColumnDataSource"},"glyph":{"id":"f0826094-06a6-47fd-8db5-1a3f45f50546","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5beb5c37-1e4d-47d7-aadd-79d64660d713","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c46690df-7742-4873-b1af-3e979ebfe29f","type":"Rect"},{"attributes":{"data_source":{"id":"18343ed5-9740-4689-a236-bce1ac44a7d3","type":"ColumnDataSource"},"glyph":{"id":"d13f83ea-6b8c-4b2b-832e-8f422cdbfe38","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3587b0ab-d305-4073-9ab5-b53fc16a6fcc","type":"GlyphRenderer"},{"attributes":{"axis_label":"Sum( Enterocount )","formatter":{"id":"55929a6d-bcf6-46b1-81f1-ae4e8a954dc0","type":"BasicTickFormatter"},"plot":{"id":"8b9aee70-1823-4c77-9927-768138a540f6","subtype":"Chart","type":"Plot"},"ticker":{"id":"82882343-d2ac-4138-8f02-d42aee7529b9","type":"BasicTicker"}},"id":"3ed1ad28-39eb-498e-b603-9bd94ec38dc4","type":"LinearAxis"},{"attributes":{"plot":{"id":"8b9aee70-1823-4c77-9927-768138a540f6","subtype":"Chart","type":"Plot"}},"id":"ff1f6701-53d4-4ac7-aa59-57f6ac853904","type":"SaveTool"},{"attributes":{"data_source":{"id":"5af404a2-48b2-423e-b8ee-3207157ffd59","type":"ColumnDataSource"},"glyph":{"id":"c46690df-7742-4873-b1af-3e979ebfe29f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"82f81a44-3311-4bdc-be2c-b8da00ead193","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8b9aee70-1823-4c77-9927-768138a540f6","subtype":"Chart","type":"Plot"}},"id":"03afebaa-0931-4df3-9f88-154bb80e84ef","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e6e8c00f-9e6e-45ab-9f4b-15f1eba0faab","type":"Rect"},{"attributes":{"data_source":{"id":"b0370c7f-6390-4a76-8027-bc7ac814ea0a","type":"ColumnDataSource"},"glyph":{"id":"05252d71-0efc-4510-920a-3164f0dd452d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"519222b8-0844-4dff-b901-dfdf212e8bb9","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"869b2f89-5cbc-418f-9af7-3786da85111d","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","width","label","height","y","fill_alpha"],"data":{"Site":["Hudson River above Troy Lock"],"chart_index":[{"Site":"Hudson River above Troy Lock"}],"color":["lightblue"],"fill_alpha":[0.8],"height":[105.36575765581442],"label":[{"Site":"Hudson River above Troy Lock"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Hudson River above Troy Lock"],"y":[52.68287882790721]}},"id":"b0370c7f-6390-4a76-8027-bc7ac814ea0a","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","width","label","height","y","fill_alpha"],"data":{"Site":["Saw Mill River"],"chart_index":[{"Site":"Saw Mill River"}],"color":["lightblue"],"fill_alpha":[0.8],"height":[115.11727721154216],"label":[{"Site":"Saw Mill River"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Saw Mill River ...

# %%
p = Bar(best, 'Site', values='EnteroCount', 
            title="Best 20 Enterococcus readings by Site",
            color="lightblue", legend=False, xlabel="")

output_file("bar.html")

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'bar.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="020dab8c-8b4e-4e00-8d97-90500e0f3356"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("020dab8c-8b4e-4e00-8d97-90500e0f3356").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("020dab8c-8b4e-4e00-8d97-90500e0f3356");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '020dab8c-8b4e-4e00-8d97-90500e0f3356' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3ed0a416-811b-4adf-a280-28e8e6793714":{"roots":{"references":[{"attributes":{"axis_label":"Sum( Enterocount )","formatter":{"id":"72c8a0d7-c5a6-42c3-bbfa-abf72b9a1ec2","type":"BasicTickFormatter"},"plot":{"id":"aef81bdf-ca03-4ca1-a36a-82e52f34fd76","subtype":"Chart","type":"Plot"},"ticker":{"id":"d0a08978-b34b-42b5-a9dd-00ebf977a83f","type":"BasicTicker"}},"id":"a0d2e724-b783-4bb2-a051-4be76cbb21f9","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2aa73791-085c-46d9-8888-0abff357e786","type":"PanTool"},{"id":"fe7e15d6-83a8-4d4f-8d50-a607d835c45d","type":"WheelZoomTool"},{"id":"37aefa9f-a997-422e-b9bb-4c5536a0db80","type":"BoxZoomTool"},{"id":"31b6776a-9220-47ae-9704-de494d615d95","type":"SaveTool"},{"id":"ce972201-6fa3-4a09-9ab2-4e344aa6829f","type":"ResetTool"},{"id":"d064abfc-ce84-4ee0-87bf-7f5ff96b88ac","type":"HelpTool"}]},"id":"2d8b0e14-114c-47d6-9e18-03425b8bb0d8","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","width","label","height","y","fill_alpha"],"data":{"Site":["Port Ewen Drinking Water Intake"],"chart_index":[{"Site":"Port Ewen Drinking Water Intake"}],"color":["lightblue"],"fill_alpha":[0.8],"height":[5.2572410288750415],"label":[{"Site":"Port Ewen Drinking Water Intake"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Port Ewen Drinking Water Intake"],"y":[2.6286205144375208]}},"id":"92cdfbfb-78b4-4d14-903e-331b22e5e31b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"195bc6bd-63e0-4ecb-996f-3b0151875db9","type":"Rect"},{"attributes":{"data_source":{"id":"d889bb2a-c2ab-4963-846b-29f387959094","type":"ColumnDataSource"},"glyph":{"id":"dbec5ed4-f9b9-4200-a654-8962979fae0c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"beec8ce8-91d4-4c6b-83e8-c34d6f95c680","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ca04efdc-de3d-4bc8-833e-c74ca96398c5","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","width","label","height","y","fill_alpha"],"data":{"Site":["Marlboro Landing"],"chart_index":[{"Site":"Marlboro Landing"}],"color":["lightblue"],"fill_alpha":[0.8],"height":[9.661642865281323],"label":[{"Site":"Marlboro Landing"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Marlboro Landing"],"y":[4.830821432640661]}},"id":"062379e6-1a43-42f7-94ba-9affb644064a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a79bd832-c0a7-49fc-9b18-d41400c56e2f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b183fa5c-45bf-45f2-8ef7-aae5f0f0aded","type":"Rect"},{"attributes":{"data_source":{"id":"6101646f-a5ee-406c-bff6-9458ede57674","type":"ColumnDataSource"},"glyph":{"id":"18d9e0a7-f3f3-4ffa-a9b4-1a272b24f6fa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f04dfa25-6633-49d2-bec7-3e09b5e3a7d3","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"2945a62c-9c1f-49c4-8977-39e624429a0d","type":"BoxAnnotation"},"plot":{"id":"aef81bdf-ca03-4ca1-a36a-82e52f34fd76","s ...

# %% [markdown]
# ### Distribution of Enterococcus Readings
# Bokeh would not let me make a simple bar chart that of all the readings that wasn't a mess. So here is a histogram showing the left skew in the data. Most of the readings are below the 30 per 100Ml level.

# %%
p = Histogram(df_geo['EnteroCount'], bins=100, 
                  title="Distribution of Geometric Means")

output_file("histogram.html",)

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'histogram.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d6f98bdd-ed39-4d0d-9a62-d6bba4124733"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d6f98bdd-ed39-4d0d-9a62-d6bba4124733").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6f98bdd-ed39-4d0d-9a62-d6bba4124733");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6f98bdd-ed39-4d0d-9a62-d6bba4124733' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b345ba7a-0f53-4d29-a6df-d6f7abd07808":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1de2e33e-1561-4754-9b76-e025bfc92a5a","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","width","label","height","y","fill_alpha"],"data":{"chart_index":["(232.310760, 236.182606]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(232.310760, 236.182606]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.871845993144774],"x":["234.246683"],"y":[0.0]}},"id":"b1d0eb9b-d874-4fa1-8b9a-8e7e851a72ff","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","width","label","height","y","fill_alpha"],"data":{"chart_index":["(294.260295, 298.132141]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(294.260295, 298.132141]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.8718459931447455],"x":["296.196218"],"y":[0.0]}},"id":"447e9fde-451a-4192-bd46-be8caa3dd579","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1af6f486-63ef-4c34-a5e0-914db52a2c1c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7b4109c7-b77c-46c3-868b-3252184694cf","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba17e53b-f66f-4203-89df-7c779460acdb","type":"Rect"},{"attributes":{"data_source":{"id":"1e98be02-ffb3-48ad-a73f-2f3ec84d1359","type":"ColumnDataSource"},"glyph":{"id":"4a95c8bf-9a69-460d-af46-4c074da23bee","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5a781a11-2768-4626-8c2b-daa004d2ed83","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","width","label","height","y","fill_alpha"],"data":{"chart_index":["(313.619525, 317.491371]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(313.619525, 317.491371]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.8718459931448024],"x":["315.555448"],"y":[0.0]}},"id":"f89f7666-f8a7-42ba-97f3-9c190873b4bb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3ccc3b5a-48e8-4aa3-afe5-631979e77ea5","type":"Rect"},{"attributes":{"data_source":{"id":"a7084537-675d-4b68-93e5-a89876789e1f","type":"ColumnDataSource"},"glyph":{"id":"d54c9039-4803-4f4d-92b7-b554d8e24cd3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bc7ec5bf-9d3a-4c9e-9bd9-43173006ad3a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b1d0eb9b-d874-4fa1-8b9a-8e7e851a72ff","type":"ColumnDataSource"},"glyph":{"id":"5949ce29-3a43-421d-80a7-29ed6e39d0f2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"eed4280a-f5b5-41bf-a097-7feb1f9a044c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"f ...

# %% [markdown]
# ***
# ## Time Span Between Measurements
# ***

# %% [markdown]
# ### Indexing on Time
# We need to create a new index based on the Date field. This will make stuff easier.

# %%
df2 = df

# %%
df2.index = df['Date']
df.head()
# Out:
#                                  Site       Date  EnteroCount  \
# Date
# 2011-10-16  Hudson above Mohawk River 2011-10-16         1733
# 2013-10-21  Hudson above Mohawk River 2013-10-21            4
# 2013-09-21  Hudson above Mohawk River 2013-09-21           20
# 2013-08-19  Hudson above Mohawk River 2013-08-19            6
# 2013-07-21  Hudson above Mohawk River 2013-07-21           31
#
#             FourDayRainTotal  SampleCount
# Date
# 2011-10-16               1.5           35
# 2013-10-21               0.2           35
# 2013-09-21               0.0           35
# 2013-08-19               0.0           35
# 2013-07-21               0.0           35

# %%
df2.resample('M', how='count')
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   if __name__ == '__main__':
#             Site  Date  EnteroCount  FourDayRainTotal  SampleCount
# Date
# 2006-09-30    18    18           18                18           18
# 2006-10-31    36    36           36                36           36
# 2006-11-30    14    14           14                14           14
# 2006-12-31    15    15           15                15           15
# 2007-01-31     0     0            0                 0            0
# 2007-02-28     0     0            0                 0            0
# 2007-03-31     0     0            0                 0            0
# 2007-04-30    26    26           26                26           26
# 2007-05-31    29    29           29                29           29
# 2007-06-30    46    46           46                46           46
# 2007-07-31    40    40           40                40           40
# 2007-08-31    33    33           33                33           33
# 2007-09-30    27    27           27                27           27
# 2007-10-31     0     0            0                 0            0
# 2007-11-30     0     0            0                 0            0
# 2007-12-31     0     0            0                 0            0
# 2008-01-31     0     0            0                 0            0
# 2008-02-29     0     0            0                 0            0
# 2008-03-31     0     0            0                 0            0
# 2008-04-30     0     0            0                 0            0
# 2008-05-31    71    71           71                71           71
# 2008-06-30    80    80           80                80           80
# 2008-07-31   111   111          111               111          111
# 2008-08-31    92    92           92                92           92
# 2008-09-30    94    94           94                94           94
# 2008-10-31    83    83           83                83           83
# 2008-11-30     0     0            0                 0            0
# 2008-12-31     0     0            0                 0            0
# 2009-01-31     2     2            2                 2            2
# 2009-02-28     9     9            9                 9            9
# ...          ...   ...          ...               ...          ...
# 2011-05-31    77    77           77                77           77
# 2011-06-30    55    55           55                55           55
# 2011-07-31    97    97           97                97           97
# 2011-08-31    74    74           74                74           74
# 2011-09-30    74    74           74                74           74
# 2011-10-31    74    74           74                74           74
# 2011-11-30     4     4            4                 4            4
# 2011-12-31     3     3            3                 3            3
# 2012-01-31     3     3            3                 3            3
# 2012-02-29     3     3            3                 3            3
# 2012-03-31     3     3            3                 3            3
# 2012-04-30     3     3            3                 3            3
# 2012-05-31    77    77           77                77           77
# 2012-06-30    81    81           81                81           81
# 2012-07-31    83    83           83                83           83
# 2012-08-31    79    79           79                79           79
# 2012-09-30    83    83           83                83           83
# 2012-10-31    81    81           81                81           81
# 2012-11-30    22    22           22                22           22
# 2012-12-31     3     3            3                 3            3
# 2013-01-31     0     0            0                 0            0
# 2013-02-28     0     0            0                 0            0
# 2013-03-31     0     0            0                 0            0
# 2013-04-30     0     0            0                 0            0
# 2013-05-31    34    34           34                34           34
# 2013-06-30   114   114          114               114          114
# 2013-07-31    74    74           74                74           74
# 2013-08-31    74    74           74                74           74
# 2013-09-30    74    74           74                74           74
# 2013-10-31    74    74           74                74           74
#
# [86 rows x 5 columns]

# %% [markdown]
# ### This lame plot ...
#
# ... is no excuse but I ran out of time trying to figure out how to do time grouping in pandas. The friggin' docs are not clear, and the examples in Bokeh and seaborn are entirely unhelpful. This is ugly and it has nothing to do with time. The overall correlation below (.14) is weak but it's clear that low water is related to high contamination in some circumstances that need to be explored.

# %%
p = Scatter(df2, 'FourDayRainTotal', 'EnteroCount', 
                  xlabel="",
                  title="Enterococcus counts by Site")

output_file("Scatter.html",)

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'Scatter.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ae0abd08-0cc6-411d-b3a7-ddff5f531653"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ae0abd08-0cc6-411d-b3a7-ddff5f531653").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ae0abd08-0cc6-411d-b3a7-ddff5f531653");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ae0abd08-0cc6-411d-b3a7-ddff5f531653' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"609e3bac-094f-43b5-bc82-8cff20939470":{"roots":{"references":[{"attributes":{"formatter":{"id":"4245c65f-5e75-46a4-8b63-6e97908c0b1e","type":"BasicTickFormatter"},"plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"},"ticker":{"id":"9b09aedc-5cb0-44b0-865e-27cfa751b1bb","type":"BasicTicker"}},"id":"7dc9754d-8160-4a18-86ea-0ac6dff8457b","type":"LinearAxis"},{"attributes":{"axis_label":"EnteroCount","formatter":{"id":"2724421c-b715-41ba-a4c2-e71e646db06f","type":"BasicTickFormatter"},"plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"},"ticker":{"id":"f473168b-b2fe-4ebb-aa2a-0ee91aae4ddd","type":"BasicTicker"}},"id":"cbede897-7f58-4d21-bbb9-40b1eebd3148","type":"LinearAxis"},{"attributes":{},"id":"2724421c-b715-41ba-a4c2-e71e646db06f","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9b8ab322-e4ba-4944-a72f-1b90ea228679","type":"PanTool"},{"id":"7e3ebe3d-905a-465d-9bbf-63d3807ca364","type":"WheelZoomTool"},{"id":"ee15864f-4dd2-4b83-8d21-25256e6feedd","type":"BoxZoomTool"},{"id":"6ad38513-9d17-440a-9d46-0037dd10296b","type":"SaveTool"},{"id":"967e8a16-e907-49a1-933d-b652af3817a0","type":"ResetTool"},{"id":"b407bf04-d0bd-43a2-9f9e-0dccde3655bf","type":"HelpTool"}]},"id":"94e43272-7e09-4c25-b4f7-54f2f684de99","type":"Toolbar"},{"attributes":{"callback":null,"end":9.35,"start":-0.8500000000000001},"id":"b0ed2bb2-e4f5-4c6d-bea5-f281943737ab","type":"Range1d"},{"attributes":{"location":"top_left","plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"}},"id":"7d513951-d74c-47e2-a5ec-d5a6632f903a","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"},"ticker":{"id":"f473168b-b2fe-4ebb-aa2a-0ee91aae4ddd","type":"BasicTicker"}},"id":"d0a0ca3f-6710-4813-a8cb-15915039a737","type":"Grid"},{"attributes":{},"id":"f473168b-b2fe-4ebb-aa2a-0ee91aae4ddd","type":"BasicTicker"},{"attributes":{"below":[{"id":"7dc9754d-8160-4a18-86ea-0ac6dff8457b","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"cbede897-7f58-4d21-bbb9-40b1eebd3148","type":"LinearAxis"}],"renderers":[{"id":"9fd65658-5549-485c-a2ef-352cafb7cecd","type":"BoxAnnotation"},{"id":"fe90706e-4c1a-403d-aa60-d88976c7de72","type":"GlyphRenderer"},{"id":"7d513951-d74c-47e2-a5ec-d5a6632f903a","type":"Legend"},{"id":"7dc9754d-8160-4a18-86ea-0ac6dff8457b","type":"LinearAxis"},{"id":"cbede897-7f58-4d21-bbb9-40b1eebd3148","type":"LinearAxis"},{"id":"6b6dcbd1-9d26-4b86-b10e-c8ca86443a6e","type":"Grid"},{"id":"d0a0ca3f-6710-4813-a8cb-15915039a737","type":"Grid"}],"title":{"id":"04caa202-0096-4110-bc74-763356b532a4","type":"Title"},"tool_events":{"id":"5d9d42c1-ded0-4d93-8368-f7e2efbb4b54","type":"ToolEvents"},"toolbar":{"id":"94e43272-7e09-4c25-b4f7-54f2f684de99","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"b0ed2bb2-e4f5-4c6d-bea5-f281943737ab","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"d7f23184-e6fb-47b9-b7e6-9b6c3b6151c1","type":"Range1d"}},"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"}},"id":"9b8ab322-e4ba-4944-a72f-1b90ea228679","type":"PanTool"},{"attributes":{"plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"}},"id":"b407bf04-d0bd-43a2-9f9e-0dccde3655bf","type":"HelpTool"},{"attributes":{"overlay":{"id":"9fd65658-5549-485c-a2ef-352cafb7cecd","type":"BoxAnnotation"},"plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"}},"id":"ee15864f-4dd2-4b83-8d21-25256e6feedd","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"4546f092-6603-41d7-9d80-296ea185915c","subtype":"Chart","type":"Plot"}},"id":"967e8a16-e907-49a1-933d-b652af3817a0","type":"ResetTool"},{"attributes":{"callback":null,"end":26615.6,"start":-2419.6 ...

# %%
np.corrcoef(df['EnteroCount'], df['FourDayRainTotal'])[1][0]
# Out:
# 0.14482598724767226
